# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavbhardwaj/AIChatBot/blob/main/grype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://gitlab.practical-devsecops.training/marudhamaran/caisp-image-classifier.git
# Out:
# Cloning into 'caisp-image-classifier'...
# remote: Enumerating objects: 123, done.
# remote: Total 123 (delta 0), reused 0 (delta 0), pack-reused 123
# Receiving objects: 100% (123/123), 19.16 MiB | 7.19 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd caisp-image-classifier
# Out:
# /content/caisp-image-classifier

# %%
! ls -al
# Out:
# total 36
# drwxr-xr-x 5 root root 4096 May  3 02:49 .
# drwxr-xr-x 1 root root 4096 May  3 02:49 ..
# drwxr-xr-x 4 root root 4096 May  3 02:49 data:image-sets
# drwxr-xr-x 8 root root 4096 May  3 02:49 .git
# -rw-r--r-- 1 root root    9 May  3 02:49 .gitignore
# -rw-r--r-- 1 root root 6184 May  3 02:49 image-classifier.py
# -rw-r--r-- 1 root root   47 May  3 02:49 requirements.txt
# drwxr-xr-x 2 root root 4096 May  3 02:49 sample-images-for-classification

# %%
! curl -sSfL https://raw.githubusercontent.com/anchore/grype/main/install.sh | sh -s -- -b /usr/local/bin
# Out:
# [info] checking github for the current release tag
# [info] fetching release script for tag='v0.112.0'
# [info] checking github for the current release tag
# [info] using release tag='v0.112.0' version='0.112.0' os='linux' arch='amd64'
# [info] installed /usr/local/bin/grype

# %%
! grype
# Out:
# A vulnerability scanner for container images, filesystems, and SBOMs.
#
# Supports the following image sources:
#     grype yourrepo/yourimage:tag             defaults to using images from a Docker daemon
#     grype path/to/yourproject                a Docker tar, OCI tar, OCI directory, SIF container, or generic filesystem directory
#
# You can also explicitly specify the scheme to use:
#     grype podman:yourrepo/yourimage:tag          explicitly use the Podman daemon
#     grype docker:yourrepo/yourimage:tag          explicitly use the Docker daemon
#     grype docker-archive:path/to/yourimage.tar   use a tarball from disk for archives created from "docker save"
#     grype oci-archive:path/to/yourimage.tar      use a tarball from disk for OCI archives (from Podman or otherwise)
#     grype oci-dir:path/to/yourimage              read directly from a path on disk for OCI layout directories (from Skopeo or otherwise)
# ...

# %%
# !grype .
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  ⠼ Vulnerability DB                ━━━━━━━━━━━━━━━━━━━━  [117 MB / 117 MB]
#
#
#
#
#
#
#  ⠴ Vulnerability DB                ━━━━━━━━━━━━━━━━━━━━  [117 MB / 117 MB]
#
#
#
#
#
#
#  ⠦ Vulnerability DB                ━━━━━━━━━━━━━━━━━━━━  [117 MB / 117 MB]
#
#
#
#
#
#
#  ⠧ Vulnerability DB                ━━━━━━━━━━━━━━━━━━━━  [117 MB / 117 MB]
#
#
#
#
#
#
#  ⠇ Vulnerability DB                ━━━━━━━━━━━━━━━━━━━━  [117 MB / 117 MB]
#
#
#
#
#
#
#  ⠏ Vulnerability DB                ━━━━━━━━━━━━━━━━━━━━  [117 MB / 117 MB]
#
#
#
#
#
#
#  ⠋ Vulnerability DB                ━━━━━━━━━━━━━━━━━━━━  [117 MB / 117 MB]
#
#
#
#
#
#
#  ⠙ Vulnerability DB                ━━━━━━━━━━━━━━━━━━━━  [117 MB / 117 MB]
#
#
#
#
#
#
#  ⠹ Vulnerability DB                ━━━━━━━━━━━━━━━━━━━━  [117 MB / 117 MB]
#
#
#
#
#
#
#  ⠸ Vulnerability DB                ━━━━━━━━━━━━━━━━━━━━  [117 MB / 117 MB]
#
#
#
#
#
#
# ...

# %%
! grype .
# Out:
#  ⠙ Cataloging contents             ━━━━━━━━━━━━━━━━━━━━  cdb4ee2aea69cc6a83331bbe96dc2caa9a299d21329efb0336fc02a82e1839a8
#    └── ⠙ Packages
#          ├── ⠋
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal) from=syft
#
#
#
#
#          ├── ⠋
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal) from=syft
#
#
#
#
#
#          ├── ⠋
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal) from=syft
#
#
#
#
#
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal) from=syft
#
#
#
#          ├── ⠙ Python package cataloger
#
#
#
#
#
#
#
#          ├── ⠋
# ...

# %%
! pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 101.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 95.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 98.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...

# %%
! grype .
# Out:
#  ✔ Indexed file system             .
#  ⠙ Cataloging contents             ━━━━━━━━━━━━━━━━━━━━  cdb4ee2aea69cc6a83331bbe96dc2caa9a299d21329efb0336fc02a82e1839a8
#    └── ⠙ Packages                        [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal) from=syft
#
#
#    └── ⠙ Packages
#          ├── ⠋
#          ├── ⠋
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal) from=syft
#
#
#
#
#
#          ├── ⠋
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal) from=syft
#
#
#
#          ├── ⠙
#          ├── ⠙
#
#          ├── ⠋
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal) from=syft
#
#
#
# ...
